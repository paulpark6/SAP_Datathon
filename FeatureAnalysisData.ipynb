# %%
import pandas as pd

# %%
rankings = pd.read_csv('data/final_rankings.csv')

# %%
df_transformed_transformed_main = pd.read_csv('data/SAP Datasets.csv')
# Out:
# C:\Users\06pau\AppData\Local\Temp\ipykernel_11116\2592756498.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_main = pd.read_csv('data/SAP Datasets.csv')

# %%
# Forward and backward filling
years_col = [str(i) for i in range(2000,2024)]
df_main[years_col] = df_main[years_col].apply(lambda row: row.ffill().bfill(), axis=1)

# %%
df_new = df_main[['Country Name', 'Country Code', 'Indicator Name', 'Topic', 'Indicator Code',
       'Unit of measure', '2022','2023']]

# %%
df_new = df_new.merge(rankings, on='Country Name', how='left')

# %%
df_new = df_new[~df_new['Indicator Name'].isin(['Population, total'])]

# %%
df_transformed = df_new.pivot(index=['Country Name', 'Country Code', 'mean_rank','rank'], columns='Indicator Name', values=['2022', '2023'])
df_transformed.columns = [f'{year}_{indicator}' for year, indicator in df_transformed.columns]
df_transformed.reset_index(inplace=True)

# %%
df_transformed.to_csv('df_transformed.csv', index=False)

# %%
df_transformed
# Out:
#                     Country Name Country Code   mean_rank  rank  \
# 0                    Afghanistan          AFG   91.966504   226
# 1    Africa Eastern and Southern          AFE  135.600571   261
# 2     Africa Western and Central          AFW  120.850325   253
# 3                        Albania          ALB   50.659578    85
# 4                        Algeria          DZA   51.366593    87
# ..                           ...          ...         ...   ...
# 261           West Bank and Gaza          PSE   57.061345   111
# 262                        World          WLD   94.292994   233
# 263                  Yemen, Rep.          YEM   75.069671   175
# 264                       Zambia          ZMB   81.969314   195
# 265                     Zimbabwe          ZWE   91.355905   224
#
#      2022_Access to clean fuels and technologies for cooking (% of population)  \
# 0                                            36.100000
# 1                                            21.863139
# 2                                            22.319404
# 3                                            84.600000
# 4                                            99.700000
# ..                                                 ...
# 261                                                NaN
# 262                                          73.843840
# 263                                          48.300000
# 264                                           9.000000
# 265                                          30.800000
#
#      2022_Access to clean fuels and technologies for cooking, rural (% of rural population)  \
# 0                                            18.500000
# 1                                             9.261320
# 2                                             6.709029
# 3                                            69.000000
# 4                                            98.900000
# ..                                                 ...
# 261                                                NaN
# 262                                          54.505338
# 263                                          26.300000
# 264                                           2.200000
# 265                                           7.200000
#
#      2022_Access to clean fuels and technologies for cooking, urban (% of urban population)  \
# 0                                            85.000000
# 1                                            41.011132
# 2                                            42.019407
# 3                                            94.500000
# 4                                            99.900000
# ..                                                 ...
# 261                                                NaN
# 262                                          88.967223
# 263                                          87.600000
# 264                                          16.600000
# 265                                          78.200000
#
#      2022_Access to electricity (% of population)  \
# 0                                       85.300000
# 1                                       48.711995
# 2                                       55.437577
# 3                                      100.000000
# 4                                      100.000000
# ..                                            ...
# 261                                    100.000000
# 262                                     91.352571
# 263                                     76.000000
# 264                                     47.800000
# 265                                     50.100000
#
#      2022_Access to electricity, rural (% of rural population)  \
# 0                                            81.700000
# 1                                            33.747907
# 2                                            25.226198
# 3                                           100.000000
# 4                                            99.300000
# ..                                                 ...
# 261                                         100.000000
# 262                                          83.986540
# 263                                          65.000000
# 264                                          14.500000
# 265                                          33.700000
#
#      2022_Access to electricity, urban (% of urban population)  ...  \
# 0                                            95.900000          ...
# 1                                            75.922121          ...
# 2                                            86.685517          ...
# 3                                           100.000000          ...
# 4                                           100.000000          ...
# ..                                                 ...          ...
# 261                                         100.000000          ...
# 262                                          97.664546          ...
# 263                                          96.100000          ...
# 264                                          87.000000          ...
# 265                                          89.000000          ...
#
#      2023_Unemployment with basic education (% of total labor force with basic education)  \
# 0                                             6.754000
# 1                                                  NaN
# 2                                             2.429684
# 3                                            10.109000
# 4                                            10.930000
# ..                                                 ...
# 261                                          21.603000
# 262                                                NaN
# 263                                          12.753000
# 264                                           4.470000
# 265                                           8.952000
#
#      2023_Unemployment with intermediate education (% of total labor force with intermediate education)  \
# 0                                             8.879000
# 1                                                  NaN
# 2                                             5.261144
# 3                                            13.279000
# 4                                            11.260000
# ..                                                 ...
# 261                                          24.009000
# 262                                                NaN
# 263                                          17.298000
# 264                                          11.044000
# 265                                          12.427000
#
#      2023_Unemployment, total (% of total labor force) (national estimate)  \
# 0                                             5.679000
# 1                                                  NaN
# 2                                             3.031437
# 3                                            11.474000
# 4                                            12.000000
# ..                                                 ...
# 261                                          24.420000
# 262                                           6.206632
# 263                                          13.467000
# 264                                           5.995000
# 265                                          10.087000
#
#      2023_Urban population (% of total population)  \
# 0                                        26.933000
# 1                                        38.335337
# 2                                        49.635410
# 3                                        64.603000
# 4                                        75.268000
# ..                                             ...
# 261                                      77.582000
# 262                                      57.337162
# 263                                      39.831000
# 264                                      46.335000
# 265                                      32.517000
#
#      2023_Wage and salaried workers, female (% of female employment) (modeled ILO estimate)  \
# 0                                             8.878202
# 1                                            20.164671
# 2                                            13.838867
# 3                                            49.573476
# 4                                            74.032838
# ..                                                 ...
# 261                                          77.067218
# 262                                          53.091130
# 263                                          34.451113
# 264                                          17.620527
# 265                                          30.630750
#
#      2023_Wage and salaried workers, male (% of male employment) (modeled ILO estimate)  \
# 0                                            18.841205
# 1                                            29.393837
# 2                                            20.440624
# 3                                            45.277198
# 4                                            67.930374
# ..                                                 ...
# 261                                          75.990584
# 262                                          51.253073
# 263                                          46.293400
# 264                                          34.436990
# 265                                          42.377150
#
#      2023_Wage and salaried workers, total (% of total employment) (modeled ILO estimate)  \
# 0                                            18.259346
# 1                                            25.069640
# 2                                            17.564789
# 3                                            47.177277
# 4                                            68.978348
# ..                                                 ...
# 261                                          76.172663
# 262                                          51.981562
# 263                                          45.522387
# 264                                          26.980686
# 265                                          36.534285
#
#      2023_Wanted fertility rate (births per woman)  \
# 0                                         4.400000
# 1                                              NaN
# 2                                         4.466846
# 3                                         1.600000
# 4                                              NaN
# ..                                             ...
# 261                                            NaN
# 262                                            NaN
# 263                                       3.100000
# 264                                       4.000000
# 265                                       3.600000
#
#      2023_Women who were first married by age 15 (% of women ages 20-24)  \
# 0                                                  9.6
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  1.4
# 4                                                  0.0
# ..                                                 ...
# 261                                                0.7
# 262                                                NaN
# 263                                                6.5
# 264                                                5.2
# 265                                                5.4
#
#      2023_Women who were first married by age 18 (% of women ages 20-24)
# 0                                                 28.7
# 1                                                  NaN
# 2                                                  NaN
# 3                                                 11.8
# 4                                                  3.8
# ..                                                 ...
# 261                                               13.4
# 262                                                NaN
# 263                                               29.6
# 264                                               29.0
# 265                                               33.7
#
# [266 rows x 178 columns]

# %%
# Out:
#   Cell In[45], line 13
#     - `2022_Access to clean fuels and technologies for cooking (% of population)`
#            ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# The `df_transformed` DataFrame is a transformed version of the `df_new` DataFrame. Here is a detailed description:
#
# ### Shape of Data
# - The `df_transformed` DataFrame has 266 rows and 178 columns.
#
# ### List of Columns
# The columns in `df_transformed` include:
# - `Country Name`
# - `Country Code`
# - `mean_rank`
# - `rank`
# - Various columns representing indicators for the years 2022 and 2023. Each indicator is prefixed with the year, followed by the indicator name. For example:
#     - `2022_Access to clean fuels and technologies for cooking (% of population)`
#     - `2023_Access to clean fuels and technologies for cooking (% of population)`
#     - `2022_Access to electricity (% of population)`
#     - `2023_Access to electricity (% of population)`
#     - And many more...
#
# ### How It Was Created
# 1. **Initial DataFrames**:
#      - `df_main`: Loaded from 'data/SAP Datasets.csv'.
#      - `rankings`: Loaded from 'data/final_rankings.csv'.
#
# 2. **Forward and Backward Filling**:
#      - The columns representing years from 2000 to 2023 in `df_main` were forward and backward filled to handle missing values.
#
# 3. **Selection of Specific Columns**:
#      - A subset of columns was selected from `df_main` to create `df_new`.
#
# 4. **Merging with Rankings**:
#      - `df_new` was merged with the `rankings` DataFrame on the 'Country Name' column using a left join.
#
# 5. **Filtering Out Specific Indicators**:
#      - Rows with the 'Indicator Name' as 'Population, total' were filtered out from `df_new`.
#
# 6. **Pivoting the DataFrame**:
#      - `df_new` was pivoted to create `df_transformed`, with 'Country Name', 'Country Code', 'mean_rank', and 'rank' as the index, and the 'Indicator Name' as columns. The values were taken from the years 2022 and 2023.
#      - The columns were then renamed to include both the year and the indicator name.
#      - The index was reset to convert the multi-index DataFrame back to a regular DataFrame.
#
# 7. **Saving to CSV**:
#      - The `df_transformed` DataFrame was saved to 'df_transformed.csv'.
#
# ### Summary
# The `df_transformed` DataFrame provides a comprehensive view of various indicators for different countries, with data for the years 2022 and 2023. It includes rankings and mean ranks for each country, along with a wide range of socio-economic and environmental indicators.

# %%
X = df_transformed.drop(columns=["Country Name", "Country Code", "mean_rank", "rank"])
y = df_transformed["mean_rank"]  # Target variable

# %%
y_rank=df_transformed['rank']

# %%
# Out:
#      2022_Multidimensional poverty headcount ratio (UNDP) (% of population)  \
# 0                                                 True
# 1                                                False
# 2                                                False
# 3                                                 True
# 4                                                 True
# ..                                                 ...
# 261                                               True
# 262                                              False
# 263                                               True
# 264                                               True
# 265                                               True
#
#      2023_Multidimensional poverty headcount ratio (UNDP) (% of population)  \
# 0                                                 True
# 1                                                False
# 2                                                False
# 3                                                 True
# 4                                                 True
# ..                                                 ...
# 261                                               True
# 262                                              False
# 263                                               True
# 264                                               True
# 265                                               True
#
#      2023_Wage and salaried workers, female (% of female employment) (modeled ILO estimate)  \
# 0                                                 True
# 1                                                 True
# 2                                                 True
# 3                                                 True
# 4                                                 True
# ..                                                 ...
# 261                                               True
# 262                                               True
# 263                                               True
# 264                                               True
# 265                                               True
#
#      2022_Wage and salaried workers, female (% of female employment) (modeled ILO estimate)  \
# 0                                                 True
# 1                                                 True
# 2                                                 True
# 3                                                 True
# 4                                                 True
# ..                                                 ...
# 261                                               True
# 262                                               True
# 263                                               True
# 264                                               True
# 265                                               True
#
#      2023_Wage and salaried workers, total (% of total employment) (modeled ILO estimate)  \
# 0                                                 True
# 1                                                 True
# 2                                                 True
# 3                                                 True
# 4                                                 True
# ..                                                 ...
# 261                                               True
# 262                                               True
# 263                                               True
# 264                                               True
# 265                                               True
#
#      2022_Wage and salaried workers, total (% of total employment) (modeled ILO estimate)  \
# 0                                                 True
# 1                                                 True
# 2                                                 True
# 3                                                 True
# 4                                                 True
# ..                                                 ...
# 261                                               True
# 262                                               True
# 263                                               True
# 264                                               True
# 265                                               True
#
#      2023_Wage and salaried workers, male (% of male employment) (modeled ILO estimate)  \
# 0                                                 True
# 1                                                 True
# 2                                                 True
# 3                                                 True
# 4                                                 True
# ..                                                 ...
# 261                                               True
# 262                                               True
# 263                                               True
# 264                                               True
# 265                                               True
#
#      2022_Wage and salaried workers, male (% of male employment) (modeled ILO estimate)  \
# 0                                                 True
# 1                                                 True
# 2                                                 True
# 3                                                 True
# 4                                                 True
# ..                                                 ...
# 261                                               True
# 262                                               True
# 263                                               True
# 264                                               True
# 265                                               True
#
#      2023_People using safely managed drinking water services (% of population)  \
# 0                                                 True
# 1                                                False
# 2                                                 True
# 3                                                 True
# 4                                                 True
# ..                                                 ...
# 261                                               True
# 262                                               True
# 263                                              False
# 264                                              False
# 265                                               True
#
#      2022_People using safely managed drinking water services (% of population)  \
# 0                                                 True
# 1                                                False
# 2                                                 True
# 3                                                 True
# 4                                                 True
# ..                                                 ...
# 261                                               True
# 262                                               True
# 263                                              False
# 264                                              False
# 265                                               True
#
#      ...  \
# 0    ...
# 1    ...
# 2    ...
# 3    ...
# 4    ...
# ..   ...
# 261  ...
# 262  ...
# 263  ...
# 264  ...
# 265  ...
#
#      2022_Unemployment with intermediate education (% of total labor force with intermediate education)  \
# 0                                                 True
# 1                                                False
# 2                                                 True
# 3                                                 True
# 4                                                 True
# ..                                                 ...
# 261                                               True
# 262                                              False
# 263                                               True
# 264                                               True
# 265                                               True
#
#      2022_Employers, male (% of male employment) (modeled ILO estimate)  \
# 0                                                 True
# 1                                                 True
# 2                                                 True
# 3                                                 True
# 4                                                 True
# ..                                                 ...
# 261                                               True
# 262                                               True
# 263                                               True
# 264                                               True
# 265                                               True
#
#      2023_Employers, male (% of male employment) (modeled ILO estimate)  \
# 0                                                 True
# 1                                                 True
# 2                                                 True
# 3                                                 True
# 4                                                 True
# ..                                                 ...
# 261                                               True
# 262                                               True
# 263                                               True
# 264                                               True
# 265                                               True
#
#      2023_Unemployment with intermediate education (% of total labor force with intermediate education)  \
# 0                                                 True
# 1                                                False
# 2                                                 True
# 3                                                 True
# 4                                                 True
# ..                                                 ...
# 261                                               True
# 262                                              False
# 263                                               True
# 264                                               True
# 265                                               True
#
#      2023_Adequacy of social protection and labor programs (% of total welfare of beneficiary households)  \
# 0                                                 True
# 1                                                False
# 2                                                False
# 3                                                 True
# 4                                                False
# ..                                                 ...
# 261                                               True
# 262                                              False
# 263                                               True
# 264                                               True
# 265                                               True
#
#      2022_Adequacy of social protection and labor programs (% of total welfare of beneficiary households)  \
# 0                                                 True
# 1                                                False
# 2                                                False
# 3                                                 True
# 4                                                False
# ..                                                 ...
# 261                                               True
# 262                                              False
# 263                                               True
# 264                                               True
# 265                                               True
#
#      2023_Expenditure on secondary education (% of government expenditure on education)  \
# 0                                                 True
# 1                                                 True
# 2                                                 True
# 3                                                 True
# 4                                                False
# ..                                                 ...
# 261                                              False
# 262                                               True
# 263                                              False
# 264                                               True
# 265                                               True
#
#      2022_Expenditure on secondary education (% of government expenditure on education)  \
# 0                                                 True
# 1                                                 True
# 2                                                 True
# 3                                                 True
# 4                                                False
# ..                                                 ...
# 261                                              False
# 262                                               True
# 263                                              False
# 264                                               True
# 265                                               True
#
#      2022_Employers, total (% of total employment) (modeled ILO estimate)  \
# 0                                                 True
# 1                                                 True
# 2                                                 True
# 3                                                 True
# 4                                                 True
# ..                                                 ...
# 261                                               True
# 262                                               True
# 263                                               True
# 264                                               True
# 265                                               True
#
#      2023_Employers, total (% of total employment) (modeled ILO estimate)
# 0                                                 True
# 1                                                 True
# 2                                                 True
# 3                                                 True
# 4                                                 True
# ..                                                 ...
# 261                                               True
# 262                                               True
# 263                                               True
# 264                                               True
# 265                                               True
#
# [266 rows x 150 columns]

# %%
df = df_transformed[['Country Name','mean_rank']]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

# Handle missing values by filling them with the mean of the column
imputer = SimpleImputer(strategy='mean')
df['mean_rank'] = imputer.fit_transform(df[['mean_rank']])

# Scale the data (K-Means is sensitive to scale)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df[['mean_rank']])

# Find the optimal K using Elbow Method
wcss = []
K_range = range(1, 10)  # Test clusters from 1 to 10

for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)  # Sum of squared distances

# Plot Elbow Method
plt.figure(figsize=(8, 5))
plt.plot(K_range, wcss, marker='o', linestyle='--')
plt.xlabel("Number of Clusters (K)")
plt.ylabel("WCSS (Within-Cluster Sum of Squares)")
plt.title("Elbow Method for Optimal K")
plt.show()
# Out:
# C:\Users\06pau\AppData\Local\Temp\ipykernel_11116\3062322245.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mean_rank'] = imputer.fit_transform(df[['mean_rank']])

# %%
# Apply K-Means with the optimal K (adjust based on the elbow point)
optimal_k = 3  # Replace with the best K from the plot
kmeans = KMeans(n_clusters=optimal_k, random_state=42)
df['Cluster'] = kmeans.fit_predict(X_scaled)

# Sort for better readability
df = df.sort_values(by="Cluster")

print(df[['Country Name', 'mean_rank', 'Cluster']])
# Out:
#             Country Name  mean_rank  Cluster
# 157               Mexico  48.238260        0
# 60              Dominica  60.635412        0
# 254  Upper middle income  69.931082        0
# 0            Afghanistan  91.966504        0
# 6                Andorra  36.031060        0
# ..                   ...        ...      ...
# 72              Eswatini  70.053659        2
# 79         Faroe Islands  81.742938        2
# 80                  Fiji  72.921752        2
# 5         American Samoa  82.905244        2
# 121               Jordan  42.655961        2
#
# [266 rows x 3 columns]

# %%
df_transformed['cluster'] = df_transformed.merge(df[['Country Name', 'Cluster']], on='Country Name', how='left')['Cluster']

# %%
# Sort the DataFrame by 'rank'
df_transformed_sorted = df_transformed.sort_values(by='rank')

# Divide the DataFrame into 3 groups
df_transformed_sorted['group'] = pd.qcut(df_transformed_sorted['rank'], q=3, labels=[1, 2, 3])

# Display the DataFrame with the new 'group' column
df_transformed_sorted
# Out:
#                                      Country Name Country Code   mean_rank  \
# 212                                     Singapore          SGP   25.553209
# 235                                   Switzerland          CHE   26.884541
# 40                                 Cayman Islands          CYM   27.838874
# 126                                   Korea, Rep.          KOR   29.188156
# 173                                   Netherlands          NLD   29.406586
# ..                                            ...          ...         ...
# 136  Least developed countries: UN classification          LDC  139.357120
# 198                      Pre-demographic dividend          PRE  139.821747
# 100        Heavily indebted poor countries (HIPC)          HPC  141.609746
# 187                   Pacific island small states          PSS  144.611009
# 183                                Not classified          INX         NaN
#
#      rank  \
# 212     1
# 235     2
# 40      3
# 126     4
# 173     5
# ..    ...
# 136   262
# 198   263
# 100   264
# 187   265
# 183   266
#
#      2022_Access to clean fuels and technologies for cooking (% of population)  \
# 212                                         100.000000
# 235                                         100.000000
# 40                                                 NaN
# 126                                         100.000000
# 173                                         100.000000
# ..                                                 ...
# 136                                          19.988544
# 198                                          22.819071
# 100                                          16.514066
# 187                                          33.224883
# 183                                                NaN
#
#      2022_Access to clean fuels and technologies for cooking, rural (% of rural population)  \
# 212                                         100.000000
# 235                                         100.000000
# 40                                                 NaN
# 126                                         100.000000
# 173                                         100.000000
# ..                                                 ...
# 136                                           9.890226
# 198                                           9.877199
# 100                                           6.565583
# 187                                          17.001228
# 183                                                NaN
#
#      2022_Access to clean fuels and technologies for cooking, urban (% of urban population)  \
# 212                                         100.000000
# 235                                         100.000000
# 40                                                 NaN
# 126                                         100.000000
# 173                                         100.000000
# ..                                                 ...
# 136                                          38.596563
# 198                                          41.158037
# 100                                          32.251006
# 187                                          58.012982
# 183                                                NaN
#
#      2022_Access to electricity (% of population)  \
# 212                                    100.000000
# 235                                    100.000000
# 40                                     100.000000
# 126                                    100.000000
# 173                                    100.000000
# ..                                            ...
# 136                                     56.826401
# 198                                     51.120342
# 100                                     48.655393
# 187                                     85.822747
# 183                                           NaN
#
#      2022_Access to electricity, rural (% of rural population)  \
# 212                                         100.000000
# 235                                         100.000000
# 40                                          100.000000
# 126                                         100.000000
# 173                                         100.000000
# ..                                                 ...
# 136                                          45.175976
# 198                                          29.453874
# 100                                          30.833905
# 187                                          80.436384
# 183                                                NaN
#
#      2022_Access to electricity, urban (% of urban population)  ...  \
# 212                                         100.000000          ...
# 235                                         100.000000          ...
# 40                                          100.000000          ...
# 126                                         100.000000          ...
# 173                                         100.000000          ...
# ..                                                 ...          ...
# 136                                          80.734161          ...
# 198                                          80.357512          ...
# 100                                          78.648136          ...
# 187                                          93.621718          ...
# 183                                                NaN          ...
#
#      2023_Unemployment, total (% of total labor force) (national estimate)  \
# 212                                           3.444000
# 235                                           4.043000
# 40                                            4.240000
# 126                                           2.675000
# 173                                           3.537000
# ..                                                 ...
# 136                                                NaN
# 198                                                NaN
# 100                                                NaN
# 187                                           5.785721
# 183                                                NaN
#
#      2023_Urban population (% of total population)  \
# 212                                     100.000000
# 235                                      74.202000
# 40                                      100.000000
# 126                                      81.456000
# 173                                      93.179000
# ..                                             ...
# 136                                      36.376819
# 198                                      44.148376
# 100                                      38.517364
# 187                                      39.821535
# 183                                            NaN
#
#      2023_Wage and salaried workers, female (% of female employment) (modeled ILO estimate)  \
# 212                                          91.244274
# 235                                          85.957597
# 40                                                 NaN
# 126                                          79.710211
# 173                                          87.344277
# ..                                                 ...
# 136                                          17.900014
# 198                                          15.205223
# 100                                          14.424572
# 187                                          43.889884
# 183                                                NaN
#
#      2023_Wage and salaried workers, male (% of male employment) (modeled ILO estimate)  \
# 212                                          82.802156
# 235                                          81.635457
# 40                                                 NaN
# 126                                          74.167398
# 173                                          80.333192
# ..                                                 ...
# 136                                          29.574557
# 198                                          25.847024
# 100                                          24.326447
# 187                                          55.988926
# 183                                                NaN
#
#      2023_Wage and salaried workers, total (% of total employment) (modeled ILO estimate)  \
# 212                                          86.379577
# 235                                          83.649166
# 40                                                 NaN
# 126                                          76.547952
# 173                                          83.640352
# ..                                                 ...
# 136                                          24.722147
# 198                                          21.208575
# 100                                          19.914647
# 187                                          51.059063
# 183                                                NaN
#
#      2023_Wanted fertility rate (births per woman)  \
# 212                                            NaN
# 235                                            NaN
# 40                                             NaN
# 126                                            NaN
# 173                                            NaN
# ..                                             ...
# 136                                            NaN
# 198                                            NaN
# 100                                            NaN
# 187                                            NaN
# 183                                            NaN
#
#      2023_Women who were first married by age 15 (% of women ages 20-24)  \
# 212                                                0.0
# 235                                                NaN
# 40                                                 NaN
# 126                                                NaN
# 173                                                NaN
# ..                                                 ...
# 136                                                NaN
# 198                                                NaN
# 100                                                NaN
# 187                                                NaN
# 183                                                NaN
#
#      2023_Women who were first married by age 18 (% of women ages 20-24)  \
# 212                                                0.1
# 235                                                NaN
# 40                                                 NaN
# 126                                                NaN
# 173                                                NaN
# ..                                                 ...
# 136                                                NaN
# 198                                                NaN
# 100                                                NaN
# 187                                                NaN
# 183                                                NaN
#
#      cluster  group
# 212        1      1
# 235        1      1
# 40         2      1
# 126        2      1
# 173        0      1
# ..       ...    ...
# 136        1      3
# 198        1      3
# 100        1      3
# 187        2      3
# 183        2      3
#
# [266 rows x 180 columns]

# %%
df_transformed[df_transformed['cluster']==0]
# Out:
#                                      Country Name Country Code   mean_rank  \
# 0                                     Afghanistan          AFG   91.966504
# 4                                         Algeria          DZA   51.366593
# 6                                         Andorra          AND   36.031060
# 8                             Antigua and Barbuda          ATG   47.608814
# 21                                        Belgium          BEL   33.718175
# 29                                         Brazil          BRA   47.731553
# 34                                        Burundi          BDI   88.569976
# 37                                       Cameroon          CMR   79.537904
# 43                                           Chad          TCD   91.969951
# 46                                          China          CHN   57.830388
# 49                               Congo, Dem. Rep.          COD   91.059480
# 60                                       Dominica          DMA   60.635412
# 76   Europe & Central Asia (IDA & IBRD countries)          TEC   72.942452
# 89                                          Ghana          GHA   70.572031
# 93                                        Grenada          GRD   66.204375
# 127                                        Kosovo          XKX   68.265724
# 156                                     Mauritius          MUS   51.817935
# 157                                        Mexico          MEX   48.238260
# 173                                   Netherlands          NLD   29.406586
# 184                                  OECD members          OED   57.384717
# 185                                          Oman          OMN   44.001362
# 193                                          Peru          PER   55.507811
# 204                                         Samoa          WSM   65.530442
# 222                                   South Sudan          SSD  100.773960
# 254                           Upper middle income          UMC   69.931082
# 260                         Virgin Islands (U.S.)          VIR   61.587437
# 264                                        Zambia          ZMB   81.969314
# 265                                      Zimbabwe          ZWE   91.355905
#
#      rank  \
# 0     226
# 4      87
# 6      29
# 8      73
# 21     19
# 29     74
# 34    216
# 37    186
# 43    227
# 46    118
# 49    223
# 60    131
# 76    167
# 89    156
# 93    149
# 127   152
# 156    92
# 157    76
# 173     5
# 184   116
# 185    62
# 193   106
# 204   146
# 222   243
# 254   153
# 260   136
# 264   195
# 265   224
#
#      2022_Access to clean fuels and technologies for cooking (% of population)  \
# 0                                            36.100000
# 4                                            99.700000
# 6                                           100.000000
# 8                                           100.000000
# 21                                          100.000000
# 29                                           96.500000
# 34                                            0.100000
# 37                                           29.400000
# 43                                            9.500000
# 46                                           87.800000
# 49                                            4.300000
# 60                                           86.700000
# 76                                           94.684885
# 89                                           31.000000
# 93                                           84.800000
# 127                                                NaN
# 156                                          99.000000
# 157                                          85.700000
# 173                                         100.000000
# 184                                          98.119478
# 185                                         100.000000
# 193                                          88.100000
# 204                                          39.600000
# 222                                           0.000000
# 254                                          89.459134
# 260                                                NaN
# 264                                           9.000000
# 265                                          30.800000
#
#      2022_Access to clean fuels and technologies for cooking, rural (% of rural population)  \
# 0                                            18.500000
# 4                                            98.900000
# 6                                           100.000000
# 8                                           100.000000
# 21                                          100.000000
# 29                                           83.100000
# 34                                            0.100000
# 37                                            5.300000
# 43                                            0.100000
# 46                                           75.800000
# 49                                            0.700000
# 60                                           77.000000
# 76                                           88.336566
# 89                                           12.700000
# 93                                           84.050000
# 127                                                NaN
# 156                                          99.100000
# 157                                          62.600000
# 173                                         100.000000
# 184                                          94.074621
# 185                                         100.000000
# 193                                          50.500000
# 204                                          33.500000
# 222                                           0.000000
# 254                                          77.341253
# 260                                                NaN
# 264                                           2.200000
# 265                                           7.200000
#
#      2022_Access to clean fuels and technologies for cooking, urban (% of urban population)  \
# 0                                            85.000000
# 4                                            99.900000
# 6                                           100.000000
# 8                                           100.000000
# 21                                          100.000000
# 29                                           98.900000
# 34                                            0.200000
# 37                                           48.900000
# 43                                           38.600000
# 46                                           95.200000
# 49                                            8.800000
# 60                                           96.200000
# 76                                           98.689988
# 89                                           45.700000
# 93                                           93.900000
# 127                                                NaN
# 156                                          99.400000
# 157                                          91.100000
# 173                                         100.000000
# 184                                          99.115718
# 185                                         100.000000
# 193                                          97.100000
# 204                                          66.700000
# 222                                           0.000000
# 254                                          95.787919
# 260                                                NaN
# 264                                          16.600000
# 265                                          78.200000
#
#      2022_Access to electricity (% of population)  \
# 0                                       85.300000
# 4                                      100.000000
# 6                                      100.000000
# 8                                      100.000000
# 21                                     100.000000
# 29                                     100.000000
# 34                                      10.300000
# 37                                      71.000000
# 43                                      11.700000
# 46                                     100.000000
# 49                                      21.500000
# 60                                     100.000000
# 76                                      99.995407
# 89                                      85.100000
# 93                                      94.200000
# 127                                           NaN
# 156                                    100.000000
# 157                                    100.000000
# 173                                    100.000000
# 184                                    100.000000
# 185                                    100.000000
# 193                                     96.200000
# 204                                     98.300000
# 222                                      8.400000
# 254                                     99.485119
# 260                                    100.000000
# 264                                     47.800000
# 265                                     50.100000
#
#      2022_Access to electricity, rural (% of rural population)  \
# 0                                            81.700000
# 4                                            99.300000
# 6                                           100.000000
# 8                                           100.000000
# 21                                          100.000000
# 29                                           97.300000
# 34                                            1.700000
# 37                                           25.000000
# 43                                            1.300000
# 46                                          100.000000
# 49                                            1.000000
# 60                                          100.000000
# 76                                           99.984323
# 89                                           71.600000
# 93                                                 NaN
# 127                                                NaN
# 156                                         100.000000
# 157                                         100.000000
# 173                                         100.000000
# 184                                         100.000000
# 185                                         100.000000
# 193                                          85.100000
# 204                                          97.900000
# 222                                           1.700000
# 254                                          99.168825
# 260                                         100.000000
# 264                                          14.500000
# 265                                          33.700000
#
#      2022_Access to electricity, urban (% of urban population)  ...  \
# 0                                            95.900000          ...
# 4                                           100.000000          ...
# 6                                           100.000000          ...
# 8                                           100.000000          ...
# 21                                          100.000000          ...
# 29                                          100.000000          ...
# 34                                           64.000000          ...
# 37                                           94.000000          ...
# 43                                           46.300000          ...
# 46                                          100.000000          ...
# 49                                           45.300000          ...
# 60                                          100.000000          ...
# 76                                           99.671435          ...
# 89                                           95.000000          ...
# 93                                                 NaN          ...
# 127                                                NaN          ...
# 156                                          99.000000          ...
# 157                                          99.800000          ...
# 173                                         100.000000          ...
# 184                                          99.976427          ...
# 185                                         100.000000          ...
# 193                                          99.000000          ...
# 204                                         100.000000          ...
# 222                                          15.000000          ...
# 254                                          99.648479          ...
# 260                                         100.000000          ...
# 264                                          87.000000          ...
# 265                                          89.000000          ...
#
#      2023_Unemployment with intermediate education (% of total labor force with intermediate education)  \
# 0                                             8.879000
# 4                                            11.260000
# 6                                                  NaN
# 8                                                  NaN
# 21                                            6.249000
# 29                                            8.962000
# 34                                            7.009000
# 37                                           11.416000
# 43                                            3.471000
# 46                                            8.603000
# 49                                            7.492000
# 60                                                 NaN
# 76                                            7.406427
# 89                                            6.390000
# 93                                           16.600000
# 127                                          11.222000
# 156                                           5.525000
# 157                                           3.342000
# 173                                           3.216000
# 184                                           7.385351
# 185                                           3.180000
# 193                                           5.888000
# 204                                           7.331000
# 222                                           8.622000
# 254                                          11.622411
# 260                                                NaN
# 264                                          11.044000
# 265                                          12.427000
#
#      2023_Unemployment, total (% of total labor force) (national estimate)  \
# 0                                             5.679000
# 4                                            12.000000
# 6                                                  NaN
# 8                                             8.420000
# 21                                            5.528000
# 29                                            7.947000
# 34                                            1.030000
# 37                                            3.275000
# 43                                            1.135000
# 46                                            5.110000
# 49                                            1.466000
# 60                                           10.960000
# 76                                            4.935518
# 89                                            3.084000
# 93                                           13.464000
# 127                                          12.093000
# 156                                           5.571000
# 157                                           2.765000
# 173                                           3.537000
# 184                                           4.828021
# 185                                           3.300000
# 193                                           4.899000
# 204                                           5.048000
# 222                                          12.298000
# 254                                           6.635463
# 260                                                NaN
# 264                                           5.995000
# 265                                          10.087000
#
#      2023_Urban population (% of total population)  \
# 0                                        26.933000
# 4                                        75.268000
# 6                                        87.774000
# 8                                        24.332000
# 21                                       98.189000
# 29                                       87.788000
# 34                                       14.784000
# 37                                       59.315000
# 43                                       24.366000
# 46                                       64.570000
# 49                                       47.444000
# 60                                       72.006000
# 76                                       67.202278
# 89                                       59.238000
# 93                                       37.059000
# 127                                            NaN
# 156                                      40.867000
# 157                                      81.582000
# 173                                      93.179000
# 184                                      81.684892
# 185                                      88.400000
# 193                                      78.922000
# 204                                      17.508000
# 222                                      21.195000
# 254                                      68.707679
# 260                                      96.227000
# 264                                      46.335000
# 265                                      32.517000
#
#      2023_Wage and salaried workers, female (% of female employment) (modeled ILO estimate)  \
# 0                                             8.878202
# 4                                            74.032838
# 6                                                  NaN
# 8                                                  NaN
# 21                                           88.898322
# 29                                           73.063872
# 34                                            9.477477
# 37                                           17.110479
# 43                                            4.233543
# 46                                           54.536926
# 49                                            8.761552
# 60                                                 NaN
# 76                                           82.049239
# 89                                           18.119493
# 93                                                 NaN
# 127                                                NaN
# 156                                          88.651157
# 157                                          67.830863
# 173                                          87.344277
# 184                                          87.255631
# 185                                          93.252199
# 193                                          42.395402
# 204                                          67.101980
# 222                                           5.340526
# 254                                          56.303774
# 260                                          93.476850
# 264                                          17.620527
# 265                                          30.630750
#
#      2023_Wage and salaried workers, male (% of male employment) (modeled ILO estimate)  \
# 0                                            18.841205
# 4                                            67.930374
# 6                                                  NaN
# 8                                                  NaN
# 21                                           81.415361
# 29                                           64.043969
# 34                                           21.032928
# 37                                           31.969098
# 43                                           12.449101
# 46                                           53.989731
# 49                                           18.232073
# 60                                                 NaN
# 76                                           76.353840
# 89                                           31.119079
# 93                                                 NaN
# 127                                                NaN
# 156                                          78.202649
# 157                                          68.362145
# 173                                          80.333192
# 184                                          81.320603
# 185                                          96.043579
# 193                                          52.990675
# 204                                          63.574784
# 222                                          16.954651
# 254                                          56.957634
# 260                                          87.200224
# 264                                          34.436990
# 265                                          42.377150
#
#      2023_Wage and salaried workers, total (% of total employment) (modeled ILO estimate)  \
# 0                                            18.259346
# 4                                            68.978348
# 6                                                  NaN
# 8                                                  NaN
# 21                                           84.942794
# 29                                           67.872566
# 34                                           15.155129
# 37                                           24.996347
# 43                                            9.115596
# 46                                           54.238659
# 49                                           13.603677
# 60                                                 NaN
# 76                                           78.863492
# 89                                           24.894016
# 93                                                 NaN
# 127                                                NaN
# 156                                          82.191552
# 157                                          68.155556
# 173                                          83.640352
# 184                                          83.965769
# 185                                          95.603905
# 193                                          48.096138
# 204                                          64.825453
# 222                                          11.094305
# 254                                          56.679079
# 260                                          89.975486
# 264                                          26.980686
# 265                                          36.534285
#
#      2023_Wanted fertility rate (births per woman)  \
# 0                                              4.4
# 4                                              NaN
# 6                                              NaN
# 8                                              NaN
# 21                                             NaN
# 29                                             NaN
# 34                                             3.6
# 37                                             4.3
# 43                                             6.1
# 46                                             NaN
# 49                                             5.7
# 60                                             NaN
# 76                                             NaN
# 89                                             3.4
# 93                                             NaN
# 127                                            NaN
# 156                                            NaN
# 157                                            NaN
# 173                                            NaN
# 184                                            NaN
# 185                                            NaN
# 193                                            1.8
# 204                                            NaN
# 222                                            NaN
# 254                                            NaN
# 260                                            NaN
# 264                                            4.0
# 265                                            3.6
#
#      2023_Women who were first married by age 15 (% of women ages 20-24)  \
# 0                                                  9.6
# 4                                                  0.0
# 6                                                  NaN
# 8                                                  NaN
# 21                                                 0.0
# 29                                                 5.9
# 34                                                 2.8
# 37                                                10.7
# 43                                                24.2
# 46                                                 0.1
# 49                                                 8.4
# 60                                                 NaN
# 76                                                 NaN
# 89                                                 3.3
# 93                                                 NaN
# 127                                                NaN
# 156                                                NaN
# 157                                                3.6
# 173                                                NaN
# 184                                                NaN
# 185                                                1.2
# 193                                                2.0
# 204                                                0.9
# 222                                                8.9
# 254                                                NaN
# 260                                                NaN
# 264                                                5.2
# 265                                                5.4
#
#      2023_Women who were first married by age 18 (% of women ages 20-24)  \
# 0                                                 28.7
# 4                                                  3.8
# 6                                                  NaN
# 8                                                  NaN
# 21                                                 0.1
# 29                                                26.2
# 34                                                19.0
# 37                                                29.8
# 43                                                60.6
# 46                                                 2.8
# 49                                                29.1
# 60                                                 NaN
# 76                                                 NaN
# 89                                                16.1
# 93                                                 NaN
# 127                                                NaN
# 156                                                NaN
# 157                                               20.7
# 173                                                NaN
# 184                                                NaN
# 185                                                4.0
# 193                                               14.1
# 204                                                7.4
# 222                                               51.5
# 254                                                NaN
# 260                                                NaN
# 264                                               29.0
# 265                                               33.7
#
#      cluster
# 0          0
# 4          0
# 6          0
# 8          0
# 21         0
# 29         0
# 34         0
# 37         0
# 43         0
# 46         0
# 49         0
# 60         0
# 76         0
# 89         0
# 93         0
# 127        0
# 156        0
# 157        0
# 173        0
# 184        0
# 185        0
# 193        0
# 204        0
# 222        0
# 254        0
# 260        0
# 264        0
# 265        0
#
# [28 rows x 179 columns]

# %%
df_transformed.groupby(['cluster']).size()
# Out:
# cluster
# 0     28
# 1    141
# 2     97
# dtype: int64

# %%
df_transformed
# Out:
#                     Country Name Country Code   mean_rank  rank  \
# 0                    Afghanistan          AFG   91.966504   226
# 1    Africa Eastern and Southern          AFE  135.600571   261
# 2     Africa Western and Central          AFW  120.850325   253
# 3                        Albania          ALB   50.659578    85
# 4                        Algeria          DZA   51.366593    87
# ..                           ...          ...         ...   ...
# 261           West Bank and Gaza          PSE   57.061345   111
# 262                        World          WLD   94.292994   233
# 263                  Yemen, Rep.          YEM   75.069671   175
# 264                       Zambia          ZMB   81.969314   195
# 265                     Zimbabwe          ZWE   91.355905   224
#
#      2022_Access to clean fuels and technologies for cooking (% of population)  \
# 0                                            36.100000
# 1                                            21.863139
# 2                                            22.319404
# 3                                            84.600000
# 4                                            99.700000
# ..                                                 ...
# 261                                                NaN
# 262                                          73.843840
# 263                                          48.300000
# 264                                           9.000000
# 265                                          30.800000
#
#      2022_Access to clean fuels and technologies for cooking, rural (% of rural population)  \
# 0                                            18.500000
# 1                                             9.261320
# 2                                             6.709029
# 3                                            69.000000
# 4                                            98.900000
# ..                                                 ...
# 261                                                NaN
# 262                                          54.505338
# 263                                          26.300000
# 264                                           2.200000
# 265                                           7.200000
#
#      2022_Access to clean fuels and technologies for cooking, urban (% of urban population)  \
# 0                                            85.000000
# 1                                            41.011132
# 2                                            42.019407
# 3                                            94.500000
# 4                                            99.900000
# ..                                                 ...
# 261                                                NaN
# 262                                          88.967223
# 263                                          87.600000
# 264                                          16.600000
# 265                                          78.200000
#
#      2022_Access to electricity (% of population)  \
# 0                                       85.300000
# 1                                       48.711995
# 2                                       55.437577
# 3                                      100.000000
# 4                                      100.000000
# ..                                            ...
# 261                                    100.000000
# 262                                     91.352571
# 263                                     76.000000
# 264                                     47.800000
# 265                                     50.100000
#
#      2022_Access to electricity, rural (% of rural population)  \
# 0                                            81.700000
# 1                                            33.747907
# 2                                            25.226198
# 3                                           100.000000
# 4                                            99.300000
# ..                                                 ...
# 261                                         100.000000
# 262                                          83.986540
# 263                                          65.000000
# 264                                          14.500000
# 265                                          33.700000
#
#      2022_Access to electricity, urban (% of urban population)  ...  \
# 0                                            95.900000          ...
# 1                                            75.922121          ...
# 2                                            86.685517          ...
# 3                                           100.000000          ...
# 4                                           100.000000          ...
# ..                                                 ...          ...
# 261                                         100.000000          ...
# 262                                          97.664546          ...
# 263                                          96.100000          ...
# 264                                          87.000000          ...
# 265                                          89.000000          ...
#
#      2023_Unemployment with intermediate education (% of total labor force with intermediate education)  \
# 0                                             8.879000
# 1                                                  NaN
# 2                                             5.261144
# 3                                            13.279000
# 4                                            11.260000
# ..                                                 ...
# 261                                          24.009000
# 262                                                NaN
# 263                                          17.298000
# 264                                          11.044000
# 265                                          12.427000
#
#      2023_Unemployment, total (% of total labor force) (national estimate)  \
# 0                                             5.679000
# 1                                                  NaN
# 2                                             3.031437
# 3                                            11.474000
# 4                                            12.000000
# ..                                                 ...
# 261                                          24.420000
# 262                                           6.206632
# 263                                          13.467000
# 264                                           5.995000
# 265                                          10.087000
#
#      2023_Urban population (% of total population)  \
# 0                                        26.933000
# 1                                        38.335337
# 2                                        49.635410
# 3                                        64.603000
# 4                                        75.268000
# ..                                             ...
# 261                                      77.582000
# 262                                      57.337162
# 263                                      39.831000
# 264                                      46.335000
# 265                                      32.517000
#
#      2023_Wage and salaried workers, female (% of female employment) (modeled ILO estimate)  \
# 0                                             8.878202
# 1                                            20.164671
# 2                                            13.838867
# 3                                            49.573476
# 4                                            74.032838
# ..                                                 ...
# 261                                          77.067218
# 262                                          53.091130
# 263                                          34.451113
# 264                                          17.620527
# 265                                          30.630750
#
#      2023_Wage and salaried workers, male (% of male employment) (modeled ILO estimate)  \
# 0                                            18.841205
# 1                                            29.393837
# 2                                            20.440624
# 3                                            45.277198
# 4                                            67.930374
# ..                                                 ...
# 261                                          75.990584
# 262                                          51.253073
# 263                                          46.293400
# 264                                          34.436990
# 265                                          42.377150
#
#      2023_Wage and salaried workers, total (% of total employment) (modeled ILO estimate)  \
# 0                                            18.259346
# 1                                            25.069640
# 2                                            17.564789
# 3                                            47.177277
# 4                                            68.978348
# ..                                                 ...
# 261                                          76.172663
# 262                                          51.981562
# 263                                          45.522387
# 264                                          26.980686
# 265                                          36.534285
#
#      2023_Wanted fertility rate (births per woman)  \
# 0                                         4.400000
# 1                                              NaN
# 2                                         4.466846
# 3                                         1.600000
# 4                                              NaN
# ..                                             ...
# 261                                            NaN
# 262                                            NaN
# 263                                       3.100000
# 264                                       4.000000
# 265                                       3.600000
#
#      2023_Women who were first married by age 15 (% of women ages 20-24)  \
# 0                                                  9.6
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  1.4
# 4                                                  0.0
# ..                                                 ...
# 261                                                0.7
# 262                                                NaN
# 263                                                6.5
# 264                                                5.2
# 265                                                5.4
#
#      2023_Women who were first married by age 18 (% of women ages 20-24)  \
# 0                                                 28.7
# 1                                                  NaN
# 2                                                  NaN
# 3                                                 11.8
# 4                                                  3.8
# ..                                                 ...
# 261                                               13.4
# 262                                                NaN
# 263                                               29.6
# 264                                               29.0
# 265                                               33.7
#
#      cluster
# 0          2
# 1          0
# 2          0
# 3          1
# 4          1
# ..       ...
# 261        1
# 262        2
# 263        2
# 264        2
# 265        2
#
# [266 rows x 179 columns]

# %%
## Feature selection with random forest
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Define Features (X) and Target (y)
X = df_transformed.drop(columns=["Country Name", "Country Code", "cluster"])  # Features
y = df_transformed["cluster"]  # Target (Cluster groups)

# Train Random Forest Classifier
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X, y)

# Get Feature Importances
importances = pd.Series(rf.feature_importances_, index=X.columns).sort_values(ascending=False)

# Plot Top 20 Important Features
plt.figure(figsize=(10, 6))
importances[:20].plot(kind="barh", color="teal")
plt.xlabel("Feature Importance Score")
plt.title("Top 20 Important Features for Clustering")
plt.gca().invert_yaxis()
plt.show()

# Print Top 10 Features
print(importances.head(10))
# Out:
# rank                                                                                      0.103276
# mean_rank                                                                                 0.102519
# 2022_Access to electricity (% of population)                                              0.065423
# 2023_Access to electricity (% of population)                                              0.039381
# 2023_Access to electricity, rural (% of rural population)                                 0.036256
# 2022_Access to electricity, rural (% of rural population)                                 0.027522
# 2022_Access to electricity, urban (% of urban population)                                 0.024542
# 2022_Births attended by skilled health staff (% of total)                                 0.018269
# 2022_Access to clean fuels and technologies for cooking, rural (% of rural population)    0.018160
# 2023_People using at least basic sanitation services (% of population)                    0.017576
# dtype: float64
